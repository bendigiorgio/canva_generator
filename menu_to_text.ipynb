# %%
from paddleocr import PaddleOCR
import numpy as np
import pandas as pd

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='japan')
img_path = '/Users/bdigio17/Documents/Python_git/Python_ML/nikko_name/menu.jpg'
result = ocr.ocr(img_path, cls=True)
# Out:
# [2022/11/12 21:28:19] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/bdigio17/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/bdigio17/.paddleocr/whl/rec/japan/japan_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/Users/bdigio17/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, lang='japan', det=True, rec=True, type='ocr', ocr_version='PP-OCRv3', structure_version='PP-Structurev2')
# [2022/11/12 21:28:21] ppocr DEBUG: dt_boxes num : 63, elapse : 0.42636895179748535
# [2022/11/12 21:28:22] ppocr DEBUG: cls num  : 63, elapse : 0.6254894733428955
# [2022/11/12 21:28:30] ppocr DEBUG: rec_res num  : 63, elapse : 7.576922178268433

# %%
cur_text = list(result[0][1][1])

# %%
print(len(result[0]))
# Out:
# 46

# %%
df_columns = ["Text", "Score"]
df=pd.DataFrame(columns=df_columns)

for i in range(len(result[0])):
    cur_text = list(result[0][i][1])
    cur_text=pd.DataFrame([cur_text],columns=df_columns)
    # pd.concat([df,cur_text], ignore_index=True)
    df = df.append(cur_text)

# %%
df
# Out:
#                    Text     Score
# 0               ランチブッフェ  0.922973
# 0                   11月  0.990694
# 0               ライラキッチン  0.951934
# 0                   鉄板・  0.837281
# 0                     -  0.914419
# 0             ・ラレンチトーズト  0.808735
# 0      星のファーム・ブルーペリーツース  0.867246
# 0          肉・生ハムとうきは産の柿  0.930126
# 0      肉・チキンコンブイと葺のクレッタ  0.851550
# 0              オレンジのソース  0.817584
# 0          魚・魚イ介類のパナッシュ  0.918628
# 0               アイォリリニス  0.885084
# 0         魚・海老とレンコンのサラタ  0.960568
# 0                アメリカン風  0.731640
# 0        町・ナガリキのエス方ーサショ  0.670782
# 0  野ー宗像めくみ卵の温度卿のカルホナーラ風  0.869413
# 0  野ャビニリとケリームキーズのタルトレット  0.796326
# 0          クミン風味のオレンジ系え  0.805209
# 0                  サラ々ー  0.678955
# 0                  温製料理  0.862061
# 0             肉・ホーク重ース千  0.608626
# 0                メイプル風味  0.848587
# 0            肉・チキンのロースト  0.969787
# 0       ル参ピューレとバレサミヨツース  0.859442
# 0     肉・チキンのノルマンディー風者込み  0.933728
# 0            魚・島身黒のロ一スト  0.838501
# 0            トマトクリームンース  0.974816
# 0         真請とムールのュトリャード  0.910198
# 0            香章ドレッシンク添え  0.920019
# 0      魚・カレイとンネガイモのクラタン  0.945854
# 0                     野  1.000000
# 0              根菜の軽い煮込の  0.857085
# 0                     野  0.999703
# 0                モの茶レ野菜  0.642369
# 0                ３種のソーズ  0.840219
# 0                     プ  0.646104
# 0         マンラックングラムチャウグ  0.828087
# 0        フ・宗のマの即の中華風スーフ  0.698401
# 0            ア・ロのリンクバスク  0.640961
# 0          パ・オロのンョートパフク  0.794904
# 0            カキオテリレサレッー  0.513152
# 0              彼・オロのビラフ  0.845766
# 0                   アライ  0.738139
# 0                  ドボテト  0.686973
# 0                 (クラクツ  0.804706
# 0                ツツパークリ  0.678915
